# %%
import pandas as pd
import altair as alt

dataSetA = pd.read_csv('world.csv')
dataSetB = pd.read_csv('vacs.csv')
dataSetC = pd.read_csv('earthquake_1995-2023.csv')

# selected_columns = df.loc[:, ['Column1', 'Column2', 'Column3']]

dataSetCfiltered = dataSetC.loc[:, ['magnitude', 'date_time', 'country']]
dataSetCfiltered_by_country = dataSetCfiltered.groupby(['country'])['magnitude'].max()
dataSetA.columns = dataSetA.columns.str.upper()
dataSetB.columns = dataSetB.columns.str.upper()

# Merge the DataFrames based on the 'Country' column

merged_data = pd.merge(dataSetA, dataSetB, on='COUNTRY')
merged_data2 = pd.merge(dataSetCfiltered, dataSetCfiltered_by_country, on='country')
merged_data3 = merged_data2.drop_duplicates(subset = ['country'])
dataSetCfiltered_by_country.head()
merged_data4 = merged_data3.drop('magnitude_x', axis=1)
merged_data4.columns = merged_data4.columns.str.upper()

merge_data5 = pd.merge(dataSetA, merged_data4, on='COUNTRY')
merge_data5.head()
# Out:
#        COUNTRY DENSITY\n(P/KM2) ABBREVIATION AGRICULTURAL LAND( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Algeria               18           DZ                17.40%
# 2    Argentina               17           AR                54.30%
# 3   Azerbaijan              123           AZ                57.70%
# 4      Bolivia               11           BO                34.80%
#
#   LAND AREA(KM2) ARMED FORCES SIZE  BIRTH RATE  CALLING CODE  \
# 0        652,230           323,000       32.49          93.0
# 1      2,381,741           317,000       24.28         213.0
# 2      2,780,400           105,000       17.02          54.0
# 3         86,600            82,000       14.00         994.0
# 4      1,098,581            71,000       21.75         591.0
#
#   CAPITAL/MAJOR CITY CO2-EMISSIONS     CPI CPI CHANGE (%) CURRENCY-CODE  \
# 0              Kabul         8,672   149.9          2.30%           AFN
# 1            Algiers       150,006  151.36          2.00%           DZD
# 2       Buenos Aires       201,348  232.75         53.50%           ARS
# 3               Baku        37,620  156.32          2.60%           AZN
# 4              Sucre        21,606  148.32          1.80%           BOB
#
#    FERTILITY RATE FORESTED AREA (%) GASOLINE PRICE                GDP  \
# 0            4.47             2.10%         $0.70    $19,101,353,833
# 1            3.02             0.80%         $0.28   $169,988,236,398
# 2            2.26             9.80%         $1.10   $449,663,446,954
# 3            1.73            14.10%         $0.56    $39,207,000,000
# 4            2.73            50.30%         $0.71    $40,895,322,865
#
#   GROSS PRIMARY EDUCATION ENROLLMENT (%)  \
# 0                                104.00%
# 1                                109.90%
# 2                                109.70%
# 3                                 99.70%
# 4                                 98.20%
#
#   GROSS TERTIARY EDUCATION ENROLLMENT (%)  INFANT MORTALITY  \
# 0                                   9.70%              47.9
# 1                                  51.40%              20.1
# 2                                  90.00%               8.8
# 3                                  27.70%              19.2
# 4                                     NaN              21.8
#
#               LARGEST CITY  LIFE EXPECTANCY  MATERNAL MORTALITY RATIO  \
# 0                    Kabul             64.5                     638.0
# 1                  Algiers             76.7                     112.0
# 2             Buenos Aires             76.5                      39.0
# 3                     Baku             72.9                      26.0
# 4  Santa Cruz de la Sierra             71.2                     155.0
#
#   MINIMUM WAGE     OFFICIAL LANGUAGE OUT OF POCKET HEALTH EXPENDITURE  \
# 0       $0.43                 Pashto                           78.40%
# 1       $0.95                 Arabic                           28.10%
# 2       $3.35                Spanish                           17.60%
# 3       $0.47   Azerbaijani language                           78.60%
# 4       $1.36                Spanish                           25.90%
#
#    PHYSICIANS PER THOUSAND  POPULATION  \
# 0                     0.28  38,041,754
# 1                     1.72  43,053,054
# 2                     3.96  44,938,712
# 3                     3.45  10,023,318
# 4                     1.59  11,513,100
#
#   POPULATION: LABOR FORCE PARTICIPATION (%) TAX REVENUE (%) TOTAL TAX RATE  \
# 0                                    48.90%           9.30%         71.40%
# 1                                    41.20%          37.20%         66.10%
# 2                                    61.30%          10.10%        106.30%
# 3                                    66.50%          13.00%         40.70%
# 4                                    71.80%          17.00%         83.70%
#
#   UNEMPLOYMENT RATE URBAN_POPULATION   LATITUDE  LONGITUDE         DATE_TIME  \
# 0            11.12%        9,797,273  33.939110  67.709953  21-03-2023 16:47
# 1            11.70%       31,510,100  28.033886   1.659626  21-05-2003 18:44
# 2             9.79%       41,339,571 -38.416097 -63.616672  17-07-2023 03:05
# 3             5.51%        5,616,165  40.143105  47.576927  25-11-2000 18:10
# 4             3.50%        8,033,035 -16.290154 -63.588653  02-04-2018 13:40
#
#    MAGNITUDE_Y
# 0          7.5
# 1          6.8
# 2          7.2
# 3          6.8
# 4          6.8

# %%
m5_filtered = merge_data5.drop(['LONGITUDE', 'LATITUDE','ABBREVIATION', 'LARGEST CITY','CALLING CODE','GROSS TERTIARY EDUCATION ENROLLMENT (%)'], axis = 1)

# %%
m5_filtered = m5_filtered.dropna()
m5_filtered.head()
# Out:
#        COUNTRY DENSITY\n(P/KM2) AGRICULTURAL LAND( %) LAND AREA(KM2)  \
# 0  Afghanistan               60                58.10%        652,230
# 1      Algeria               18                17.40%      2,381,741
# 2    Argentina               17                54.30%      2,780,400
# 3   Azerbaijan              123                57.70%         86,600
# 4      Bolivia               11                34.80%      1,098,581
#
#   ARMED FORCES SIZE  BIRTH RATE CAPITAL/MAJOR CITY CO2-EMISSIONS     CPI  \
# 0           323,000       32.49              Kabul         8,672   149.9
# 1           317,000       24.28            Algiers       150,006  151.36
# 2           105,000       17.02       Buenos Aires       201,348  232.75
# 3            82,000       14.00               Baku        37,620  156.32
# 4            71,000       21.75              Sucre        21,606  148.32
#
#   CPI CHANGE (%) CURRENCY-CODE  FERTILITY RATE FORESTED AREA (%)  \
# 0          2.30%           AFN            4.47             2.10%
# 1          2.00%           DZD            3.02             0.80%
# 2         53.50%           ARS            2.26             9.80%
# 3          2.60%           AZN            1.73            14.10%
# 4          1.80%           BOB            2.73            50.30%
#
#   GASOLINE PRICE                GDP GROSS PRIMARY EDUCATION ENROLLMENT (%)  \
# 0         $0.70    $19,101,353,833                                 104.00%
# 1         $0.28   $169,988,236,398                                 109.90%
# 2         $1.10   $449,663,446,954                                 109.70%
# 3         $0.56    $39,207,000,000                                  99.70%
# 4         $0.71    $40,895,322,865                                  98.20%
#
#    INFANT MORTALITY  LIFE EXPECTANCY  MATERNAL MORTALITY RATIO MINIMUM WAGE  \
# 0              47.9             64.5                     638.0       $0.43
# 1              20.1             76.7                     112.0       $0.95
# 2               8.8             76.5                      39.0       $3.35
# 3              19.2             72.9                      26.0       $0.47
# 4              21.8             71.2                     155.0       $1.36
#
#       OFFICIAL LANGUAGE OUT OF POCKET HEALTH EXPENDITURE  \
# 0                Pashto                           78.40%
# 1                Arabic                           28.10%
# 2               Spanish                           17.60%
# 3  Azerbaijani language                           78.60%
# 4               Spanish                           25.90%
#
#    PHYSICIANS PER THOUSAND  POPULATION  \
# 0                     0.28  38,041,754
# 1                     1.72  43,053,054
# 2                     3.96  44,938,712
# 3                     3.45  10,023,318
# 4                     1.59  11,513,100
#
#   POPULATION: LABOR FORCE PARTICIPATION (%) TAX REVENUE (%) TOTAL TAX RATE  \
# 0                                    48.90%           9.30%         71.40%
# 1                                    41.20%          37.20%         66.10%
# 2                                    61.30%          10.10%        106.30%
# 3                                    66.50%          13.00%         40.70%
# 4                                    71.80%          17.00%         83.70%
#
#   UNEMPLOYMENT RATE URBAN_POPULATION         DATE_TIME  MAGNITUDE_Y
# 0            11.12%        9,797,273  21-03-2023 16:47          7.5
# 1            11.70%       31,510,100  21-05-2003 18:44          6.8
# 2             9.79%       41,339,571  17-07-2023 03:05          7.2
# 3             5.51%        5,616,165  25-11-2000 18:10          6.8
# 4             3.50%        8,033,035  02-04-2018 13:40          6.8

# %%
pd.set_option('display.max_columns', None)
m5_filtered.head()
# Out:
#        COUNTRY DENSITY\n(P/KM2) AGRICULTURAL LAND( %) LAND AREA(KM2)  \
# 0  Afghanistan               60                58.10%        652,230
# 1      Algeria               18                17.40%      2,381,741
# 2    Argentina               17                54.30%      2,780,400
# 3   Azerbaijan              123                57.70%         86,600
# 4      Bolivia               11                34.80%      1,098,581
#
#   ARMED FORCES SIZE  BIRTH RATE CAPITAL/MAJOR CITY CO2-EMISSIONS     CPI  \
# 0           323,000       32.49              Kabul         8,672   149.9
# 1           317,000       24.28            Algiers       150,006  151.36
# 2           105,000       17.02       Buenos Aires       201,348  232.75
# 3            82,000       14.00               Baku        37,620  156.32
# 4            71,000       21.75              Sucre        21,606  148.32
#
#   CPI CHANGE (%) CURRENCY-CODE  FERTILITY RATE FORESTED AREA (%)  \
# 0          2.30%           AFN            4.47             2.10%
# 1          2.00%           DZD            3.02             0.80%
# 2         53.50%           ARS            2.26             9.80%
# 3          2.60%           AZN            1.73            14.10%
# 4          1.80%           BOB            2.73            50.30%
#
#   GASOLINE PRICE                GDP GROSS PRIMARY EDUCATION ENROLLMENT (%)  \
# 0         $0.70    $19,101,353,833                                 104.00%
# 1         $0.28   $169,988,236,398                                 109.90%
# 2         $1.10   $449,663,446,954                                 109.70%
# 3         $0.56    $39,207,000,000                                  99.70%
# 4         $0.71    $40,895,322,865                                  98.20%
#
#    INFANT MORTALITY  LIFE EXPECTANCY  MATERNAL MORTALITY RATIO MINIMUM WAGE  \
# 0              47.9             64.5                     638.0       $0.43
# 1              20.1             76.7                     112.0       $0.95
# 2               8.8             76.5                      39.0       $3.35
# 3              19.2             72.9                      26.0       $0.47
# 4              21.8             71.2                     155.0       $1.36
#
#       OFFICIAL LANGUAGE OUT OF POCKET HEALTH EXPENDITURE  \
# 0                Pashto                           78.40%
# 1                Arabic                           28.10%
# 2               Spanish                           17.60%
# 3  Azerbaijani language                           78.60%
# 4               Spanish                           25.90%
#
#    PHYSICIANS PER THOUSAND  POPULATION  \
# 0                     0.28  38,041,754
# 1                     1.72  43,053,054
# 2                     3.96  44,938,712
# 3                     3.45  10,023,318
# 4                     1.59  11,513,100
#
#   POPULATION: LABOR FORCE PARTICIPATION (%) TAX REVENUE (%) TOTAL TAX RATE  \
# 0                                    48.90%           9.30%         71.40%
# 1                                    41.20%          37.20%         66.10%
# 2                                    61.30%          10.10%        106.30%
# 3                                    66.50%          13.00%         40.70%
# 4                                    71.80%          17.00%         83.70%
#
#   UNEMPLOYMENT RATE URBAN_POPULATION         DATE_TIME  MAGNITUDE_Y
# 0            11.12%        9,797,273  21-03-2023 16:47          7.5
# 1            11.70%       31,510,100  21-05-2003 18:44          6.8
# 2             9.79%       41,339,571  17-07-2023 03:05          7.2
# 3             5.51%        5,616,165  25-11-2000 18:10          6.8
# 4             3.50%        8,033,035  02-04-2018 13:40          6.8

# %%
m5_filtered.size
# Out:
# 1054

# %%
data = m5_filtered

# %%
whr = pd.read_csv("WHR2023.csv")
whr.head()
# Out:
#   Country name  Ladder score  Standard error of ladder score  upperwhisker  \
# 0      Finland         7.804                           0.036         7.875
# 1      Denmark         7.586                           0.041         7.667
# 2      Iceland         7.530                           0.049         7.625
# 3       Israel         7.473                           0.032         7.535
# 4  Netherlands         7.403                           0.029         7.460
#
#    lowerwhisker  Logged GDP per capita  Social support  \
# 0         7.733                 10.792           0.969
# 1         7.506                 10.962           0.954
# 2         7.434                 10.896           0.983
# 3         7.411                 10.639           0.943
# 4         7.346                 10.942           0.930
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                   71.150                         0.961      -0.019
# 1                   71.250                         0.934       0.134
# 2                   72.050                         0.936       0.211
# 3                   72.697                         0.809      -0.023
# 4                   71.550                         0.887       0.213
#
#    Perceptions of corruption  Ladder score in Dystopia  \
# 0                      0.182                     1.778
# 1                      0.196                     1.778
# 2                      0.668                     1.778
# 3                      0.708                     1.778
# 4                      0.379                     1.778
#
#    Explained by: Log GDP per capita  Explained by: Social support  \
# 0                             1.888                         1.585
# 1                             1.949                         1.548
# 2                             1.926                         1.620
# 3                             1.833                         1.521
# 4                             1.942                         1.488
#
#    Explained by: Healthy life expectancy  \
# 0                                  0.535
# 1                                  0.537
# 2                                  0.559
# 3                                  0.577
# 4                                  0.545
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.772                     0.126
# 1                                       0.734                     0.208
# 2                                       0.738                     0.250
# 3                                       0.569                     0.124
# 4                                       0.672                     0.251
#
#    Explained by: Perceptions of corruption  Dystopia + residual
# 0                                    0.535                2.363
# 1                                    0.525                2.084
# 2                                    0.187                2.250
# 3                                    0.158                2.691
# 4                                    0.394                2.110

# %%
labels = ['Very Low', 'Low', 'Moderate', 'High', 'Very High']
levels = [1,2,3,4,5]
whr['Level Of Corruption'] = pd.cut(whr['Perceptions of corruption'], bins=5, labels = labels)
whr['Level Of Social Support in Society'] = pd.cut(whr['Social support'], bins=5, labels = labels)
whr['Generosity'] = pd.cut(whr['Generosity'], bins=5, labels = levels)
whr['Freedom to make life choices'] = pd.cut(whr['Freedom to make life choices'], bins=5, labels = levels)
whr['Ladder score'] = pd.cut(whr['Ladder score'], bins=5, labels = levels)

# %%
whr['COUNTRY'] = whr['Country name']
whr_filtered = whr[['COUNTRY', 'Generosity','Ladder score', 'Freedom to make life choices', 'Level Of Social Support in Society', 'Level Of Corruption']] 
whr_filtered.head()
# Out:
#        COUNTRY Generosity Ladder score Freedom to make life choices  \
# 0      Finland          2            5                            5
# 1      Denmark          3            5                            5
# 2      Iceland          3            5                            5
# 3       Israel          2            5                            4
# 4  Netherlands          3            5                            5
#
#   Level Of Social Support in Society Level Of Corruption
# 0                          Very High            Very Low
# 1                          Very High            Very Low
# 2                          Very High                High
# 3                          Very High                High
# 4                          Very High                 Low

# %%
data = pd.merge(data, whr_filtered, on='COUNTRY')

# %%
data.head()
# Out:
#        COUNTRY DENSITY\n(P/KM2) AGRICULTURAL LAND( %) LAND AREA(KM2)  \
# 0  Afghanistan               60                58.10%        652,230
# 1      Algeria               18                17.40%      2,381,741
# 2    Argentina               17                54.30%      2,780,400
# 3      Bolivia               11                34.80%      1,098,581
# 4     Botswana                4                45.60%        581,730
#
#   ARMED FORCES SIZE  BIRTH RATE CAPITAL/MAJOR CITY CO2-EMISSIONS     CPI  \
# 0           323,000       32.49              Kabul         8,672   149.9
# 1           317,000       24.28            Algiers       150,006  151.36
# 2           105,000       17.02       Buenos Aires       201,348  232.75
# 3            71,000       21.75              Sucre        21,606  148.32
# 4             9,000       24.82           Gaborone         6,340  149.75
#
#   CPI CHANGE (%) CURRENCY-CODE  FERTILITY RATE FORESTED AREA (%)  \
# 0          2.30%           AFN            4.47             2.10%
# 1          2.00%           DZD            3.02             0.80%
# 2         53.50%           ARS            2.26             9.80%
# 3          1.80%           BOB            2.73            50.30%
# 4          2.80%           BWP            2.87            18.90%
#
#   GASOLINE PRICE                GDP GROSS PRIMARY EDUCATION ENROLLMENT (%)  \
# 0         $0.70    $19,101,353,833                                 104.00%
# 1         $0.28   $169,988,236,398                                 109.90%
# 2         $1.10   $449,663,446,954                                 109.70%
# 3         $0.71    $40,895,322,865                                  98.20%
# 4         $0.71    $18,340,510,789                                 103.20%
#
#    INFANT MORTALITY  LIFE EXPECTANCY  MATERNAL MORTALITY RATIO MINIMUM WAGE  \
# 0              47.9             64.5                     638.0       $0.43
# 1              20.1             76.7                     112.0       $0.95
# 2               8.8             76.5                      39.0       $3.35
# 3              21.8             71.2                     155.0       $1.36
# 4              30.0             69.3                     144.0       $0.29
#
#   OFFICIAL LANGUAGE OUT OF POCKET HEALTH EXPENDITURE  PHYSICIANS PER THOUSAND  \
# 0            Pashto                           78.40%                     0.28
# 1            Arabic                           28.10%                     1.72
# 2           Spanish                           17.60%                     3.96
# 3           Spanish                           25.90%                     1.59
# 4           English                            5.30%                     0.37
#
#    POPULATION POPULATION: LABOR FORCE PARTICIPATION (%) TAX REVENUE (%)  \
# 0  38,041,754                                    48.90%           9.30%
# 1  43,053,054                                    41.20%          37.20%
# 2  44,938,712                                    61.30%          10.10%
# 3  11,513,100                                    71.80%          17.00%
# 4   2,346,179                                    70.80%          19.50%
#
#   TOTAL TAX RATE UNEMPLOYMENT RATE URBAN_POPULATION         DATE_TIME  \
# 0         71.40%            11.12%        9,797,273  21-03-2023 16:47
# 1         66.10%            11.70%       31,510,100  21-05-2003 18:44
# 2        106.30%             9.79%       41,339,571  17-07-2023 03:05
# 3         83.70%             3.50%        8,033,035  02-04-2018 13:40
# 4         25.10%            18.19%        1,616,550  03-04-2017 17:40
#
#    MAGNITUDE_Y Generosity Ladder score Freedom to make life choices  \
# 0          7.5          2            1                            1
# 1          6.8          1            3                            2
# 2          7.2          2            4                            4
# 3          6.8          2            4                            5
# 4          6.5          1            2                            4
#
#   Level Of Social Support in Society Level Of Corruption
# 0                           Very Low           Very High
# 1                          Very High                High
# 2                          Very High           Very High
# 3                               High           Very High
# 4                               High           Very High

# %%
data['date'] = pd.to_datetime(data['DATE_TIME']).dt.date
data['density'] = data['DENSITY\n(P/KM2)']
data['GDP'] = data['GDP'].str.replace(',', '').str.replace(' ', '').str.replace('$', '').astype(float)
data['CO2-EMISSIONS'] = data['CO2-EMISSIONS'].str.replace(',', '').str.replace(' ', '')
data['FORESTED AREA (%)'] = data['FORESTED AREA (%)'].str.replace('%', '').str.replace(' ', '')
data['POPULATION'] = data['POPULATION'].str.replace(',', '').str.replace(' ', '')
data['TOTAL TAX RATE'] = data['TOTAL TAX RATE'].str.replace('%', '').str.replace(' ', '')
data['UNEMPLOYMENT RATE'] = data['UNEMPLOYMENT RATE'].str.replace('%', '').str.replace(' ', '')
data['MINIMUM WAGE'] = data['MINIMUM WAGE'].str.replace('$', '').astype(float)
data['density'] = pd.to_numeric(data['density'], errors='coerce')
data['FORESTED AREA (%)'] = pd.to_numeric(data['FORESTED AREA (%)'], errors='coerce')
data['PHYSICIANS PER THOUSAND'] = pd.to_numeric(data['PHYSICIANS PER THOUSAND'], errors='coerce')
data['TOTAL TAX RATE'] = pd.to_numeric(data['TOTAL TAX RATE'], errors='coerce')
data['UNEMPLOYMENT RATE'] = pd.to_numeric(data['UNEMPLOYMENT RATE'], errors='coerce')
data['CO2-EMISSIONS'] = pd.to_numeric(data['CO2-EMISSIONS'], errors='coerce')
data['POPULATION'] = pd.to_numeric(data['POPULATION'], errors='coerce')
# Out:
# /var/folders/rd/9nbcv3cs77b4zg8s993nhqrc0000gn/T/ipykernel_52960/1068241553.py:1: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['date'] = pd.to_datetime(data['DATE_TIME']).dt.date

# %%
data = data[['date', 'COUNTRY', 'CAPITAL/MAJOR CITY','CURRENCY-CODE', 'density', 'BIRTH RATE','CO2-EMISSIONS', 'FERTILITY RATE', 'FORESTED AREA (%)', 'GDP', 'INFANT MORTALITY',  'LIFE EXPECTANCY', 'MINIMUM WAGE', 'OFFICIAL LANGUAGE','PHYSICIANS PER THOUSAND', 'POPULATION', 'TOTAL TAX RATE', 'UNEMPLOYMENT RATE', 'Generosity', 'Ladder score','Freedom to make life choices', 'Level Of Social Support in Society', 'Level Of Corruption']]

# %%
data.head()
# Out:
#          date      COUNTRY CAPITAL/MAJOR CITY CURRENCY-CODE  density  \
# 0  2023-03-21  Afghanistan              Kabul           AFN       60
# 1  2003-05-21      Algeria            Algiers           DZD       18
# 2  2023-07-17    Argentina       Buenos Aires           ARS       17
# 3  2018-04-02      Bolivia              Sucre           BOB       11
# 4  2017-04-03     Botswana           Gaborone           BWP        4
#
#    BIRTH RATE  CO2-EMISSIONS  FERTILITY RATE  FORESTED AREA (%)           GDP  \
# 0       32.49           8672            4.47                2.1  1.910135e+10
# 1       24.28         150006            3.02                0.8  1.699882e+11
# 2       17.02         201348            2.26                9.8  4.496634e+11
# 3       21.75          21606            2.73               50.3  4.089532e+10
# 4       24.82           6340            2.87               18.9  1.834051e+10
#
#    INFANT MORTALITY  LIFE EXPECTANCY  MINIMUM WAGE OFFICIAL LANGUAGE  \
# 0              47.9             64.5          0.43            Pashto
# 1              20.1             76.7          0.95            Arabic
# 2               8.8             76.5          3.35           Spanish
# 3              21.8             71.2          1.36           Spanish
# 4              30.0             69.3          0.29           English
#
#    PHYSICIANS PER THOUSAND  POPULATION  TOTAL TAX RATE  UNEMPLOYMENT RATE  \
# 0                     0.28    38041754            71.4              11.12
# 1                     1.72    43053054            66.1              11.70
# 2                     3.96    44938712           106.3               9.79
# 3                     1.59    11513100            83.7               3.50
# 4                     0.37     2346179            25.1              18.19
#
#   Generosity Ladder score Freedom to make life choices  \
# 0          2            1                            1
# 1          1            3                            2
# 2          2            4                            4
# 3          2            4                            5
# 4          1            2                            4
#
#   Level Of Social Support in Society Level Of Corruption
# 0                           Very Low           Very High
# 1                          Very High                High
# 2                          Very High           Very High
# 3                               High           Very High
# 4                               High           Very High

# %%
print(data.describe())
# Out:
#           density  BIRTH RATE  CO2-EMISSIONS  FERTILITY RATE  \
# count   29.000000   29.000000   2.900000e+01       29.000000
# mean    86.275862   20.529310   2.796486e+05        2.573103
# std    113.278701    7.601478   5.430939e+05        0.956243
# min      2.000000    8.100000   5.310000e+03        1.350000
# 25%     18.000000   14.880000   9.787000e+03        1.810000
# 50%     46.000000   18.780000   5.741400e+04        2.310000
# 75%     83.000000   24.560000   2.013480e+05        2.900000
# max    464.000000   37.520000   2.407672e+06        4.890000
#
#        FORESTED AREA (%)           GDP  INFANT MORTALITY  LIFE EXPECTANCY  \
# count          29.000000  2.900000e+01         29.000000        29.000000
# mean           28.979310  4.565437e+11         20.706897        73.068966
# std            20.203542  6.801804e+11         14.861358         5.477493
# min             0.500000  8.116627e+09          3.600000        60.200000
# 25%             8.000000  3.064138e+10          8.800000        69.700000
# 50%            27.800000  2.069288e+11         16.900000        72.700000
# 75%            49.800000  4.453453e+11         29.900000        76.500000
# max            58.900000  2.611000e+12         57.200000        81.900000
#
#        MINIMUM WAGE  PHYSICIANS PER THOUSAND    POPULATION  TOTAL TAX RATE  \
# count     29.000000                29.000000  2.900000e+01       29.000000
# mean       1.810000                 1.760000  1.016513e+08       47.003448
# std        2.657972                 1.358615  2.530203e+08       20.429504
# min        0.090000                 0.010000  2.346179e+06       15.700000
# 25%        0.390000                 0.680000  1.071632e+07       33.900000
# 50%        0.950000                 1.590000  3.426853e+07       43.100000
# 75%        1.600000                 2.610000  5.800546e+07       60.600000
# max       11.490000                 5.480000  1.366418e+09      106.300000
#
#        UNEMPLOYMENT RATE
# count          29.000000
# mean            7.056207
# std             4.521431
# min             1.410000
# 25%             3.500000
# 50%             5.930000
# 75%            11.020000
# max            18.190000

# %%
# Calculate value counts for 'OFFICIAL LANGUAGE', 'Generosity', 'Ladder score',
# 'Freedom to make life choices', 'Level Of Social Support in Society', 'Level Of Corruption', and 'CURRENCY-CODE'
language_counts = data['OFFICIAL LANGUAGE'].value_counts().reset_index()
language_counts.columns = ['OFFICIAL LANGUAGE', 'Count']

generosity_counts = data['Generosity'].value_counts().reset_index()
generosity_counts.columns = ['Generosity', 'Count']

ladder_score_counts = data['Ladder score'].value_counts().reset_index()
ladder_score_counts.columns = ['Ladder score', 'Count']

freedom_counts = data['Freedom to make life choices'].value_counts().reset_index()
freedom_counts.columns = ['Freedom to make life choices', 'Count']

social_support_counts = data['Level Of Social Support in Society'].value_counts().reset_index()
social_support_counts.columns = ['Level Of Social Support in Society', 'Count']

corruption_counts = data['Level Of Corruption'].value_counts().reset_index()
corruption_counts.columns = ['Level Of Corruption', 'Count']

currency_code_counts = data['CURRENCY-CODE'].value_counts().reset_index()
currency_code_counts.columns = ['CURRENCY-CODE', 'Count']

# Print the results side by side
print("OFFICIAL LANGUAGE counts:")
print(language_counts)

print("\nGenerosity counts:")
print(generosity_counts)

print("\nLadder score counts:")
print(ladder_score_counts)

print("\nFreedom to make life choices counts:")
print(freedom_counts)

print("\nLevel Of Social Support in Society counts:")
print(social_support_counts)

print("\nLevel Of Corruption counts:")
print(corruption_counts)

print("\nCURRENCY-CODE counts:")
print(currency_code_counts)
# Out:
# OFFICIAL LANGUAGE counts:
#    OFFICIAL LANGUAGE  Count
# 0            Spanish      8
# 1            English      3
# 2             Arabic      2
# 3         Portuguese      2
# 4            Persian      2
# 5            Russian      2
# 6             Pashto      1
# 7             French      1
# 8              Greek      1
# 9              Hindi      1
# 10        Indonesian      1
# 11         Mongolian      1
# 12           Burmese      1
# 13            Nepali      1
# 14              Urdu      1
# 15           Swahili      1
#
# Generosity counts:
#   Generosity  Count
# 0          2     14
# 1          3      8
# 2          1      5
# 3          5      2
# 4          4      0
#
# Ladder score counts:
#   Ladder score  Count
# 0            4     15
# 1            3      8
# 2            2      3
# 3            5      2
# 4            1      1
#
# Freedom to make life choices counts:
#   Freedom to make life choices  Count
# 0                            5     12
# 1                            4     10
# 2                            2      3
# 3                            3      3
# 4                            1      1
#
# Level Of Social Support in Society counts:
#   Level Of Social Support in Society  Count
# 0                               High     14
# 1                          Very High     10
# 2                           Moderate      4
# 3                           Very Low      1
# 4                                Low      0
#
# Level Of Corruption counts:
#   Level Of Corruption  Count
# 0           Very High     16
# 1                High      9
# 2            Moderate      2
# 3            Very Low      1
# 4                 Low      1
#
# CURRENCY-CODE counts:
#    CURRENCY-CODE  Count
# 0            AFN      1
# 1            KGS      1
# 2            TJS      1
# 3            SAR      1
# 4            RUB      1
# 5            PHP      1
# 6            PEN      1
# 7            PKR      1
# 8            NIO      1
# 9            NZD      1
# 10           NPR      1
# 11           MMK      1
# 12           MZN      1
# 13           MNT      1
# 14           IRR      1
# 15           DZD      1
# 16           IDR      1
# 17           INR      1
# 18           GTQ      1
# 19           EUR      1
# 20           CRC      1
# 21           COP      1
# 22           CLP      1
# 23           CAD      1
# 24           BRL      1
# 25           BWP      1
# 26           BOB      1
# 27           ARS      1
# 28           TZS      1

# %%
sum(data[['COUNTRY']].value_counts())
sum(data[['OFFICIAL LANGUAGE']].value_counts())
data['GDP'].min()
# Out:
# 8116626794.0

# %%
data.to_csv('final_dataset', index=True)
# Out:
# dtype('O')

# %%
final_dataset = pd.read_csv('final_dataset')
density_hist = alt.Chart(final_dataset).mark_bar().encode(
    alt.X('density:Q', bin=alt.BinParams(maxbins=20)),
    alt.Y('count()')
)
birth_rate_hist = alt.Chart(final_dataset).mark_bar().encode(
    alt.X('BIRTH RATE:Q', bin=alt.BinParams(maxbins=12)),
    alt.Y('count()')
)
co2_hist = alt.Chart(final_dataset).mark_bar().encode(
    alt.X('CO2-EMISSIONS:Q', bin=alt.BinParams(maxbins=12)),
    alt.Y('count()')
)
fert_hist = alt.Chart(final_dataset).mark_bar().encode(
    alt.X('FERTILITY RATE:Q', bin=alt.BinParams(maxbins=12)),
    alt.Y('count()')
)
gdp_plot = alt.Chart(final_dataset).mark_boxplot().encode(
    alt.X('Level Of Corruption'),
    alt.Y('GDP')
).properties(width=400, height=300)
corruptionvsunemployment_plot = alt.Chart(final_dataset).mark_boxplot().encode(
    alt.X('Level Of Corruption'),
    alt.Y('UNEMPLOYMENT RATE')
).properties(width=400, height=300)
country_plot = alt.Chart(final_dataset).mark_circle().encode(
    alt.X('COUNTRY'),
    alt.Y('UNEMPLOYMENT RATE'),
    alt.Color('OFFICIAL LANGUAGE')
).properties(width=400, height=300)
final_dataset['result'] = final_dataset['GDP'] / final_dataset['POPULATION']
country_gdp_plot = alt.Chart(final_dataset).mark_bar().encode(
    alt.X('COUNTRY', sort = 'y'),
    alt.Y('result', title = 'GDP/Population'),
    alt.Color('UNEMPLOYMENT RATE')
).properties(width=400, height=300)
country_gdp_plot
# Out:
# alt.Chart(...)

# %%
alt.Chart(final_dataset).mark_bar().encode(
    alt.X('UNEMPLOYMENT RATE:Q', bin=alt.BinParams(maxbins=15)),
    alt.Y('result', bin=alt.BinParams(maxbins=10), title = 'GDP ADJUSTED BY POPLUATION'),
    alt.Color('TOTAL TAX RATE')
)
# Out:
# alt.Chart(...)
