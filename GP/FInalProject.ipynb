# %%
import pandas as pd
import altair as alt

dataSetA = pd.read_csv('world.csv')
dataSetC = pd.read_csv('earthquake_1995-2023.csv')

# selected_columns = df.loc[:, ['Column1', 'Column2', 'Column3']]

dataSetCfiltered = dataSetC.loc[:, ['magnitude', 'date_time', 'country']]
dataSetCfiltered_by_country = dataSetCfiltered.groupby(['country'])['magnitude'].max()
dataSetA.columns = dataSetA.columns.str.upper()

# Merge the DataFrames based on the 'Country' column
merged_data2 = pd.merge(dataSetCfiltered, dataSetCfiltered_by_country, on='country', how = 'left')

merged_data3 = merged_data2.drop('magnitude_x', axis=1)
merged_data3.columns = merged_data3.columns.str.upper()

merge_data4 = pd.merge(dataSetA, merged_data3, on='COUNTRY',how='left')
m5_filtered = merge_data4.drop(['LONGITUDE', 'LATITUDE','ABBREVIATION', 'LARGEST CITY','CALLING CODE','GROSS TERTIARY EDUCATION ENROLLMENT (%)'], axis = 1)
#This code it to see all the Columns we have available to us.
pd.set_option('display.max_columns', None)
m5_filtered.head()
data = m5_filtered

data.head()
# Out:
#        COUNTRY DENSITY\n(P/KM2) AGRICULTURAL LAND( %) LAND AREA(KM2)  \
# 0  Afghanistan               60                58.10%        652,230
# 1  Afghanistan               60                58.10%        652,230
# 2  Afghanistan               60                58.10%        652,230
# 3  Afghanistan               60                58.10%        652,230
# 4  Afghanistan               60                58.10%        652,230
#
#   ARMED FORCES SIZE  BIRTH RATE CAPITAL/MAJOR CITY CO2-EMISSIONS    CPI  \
# 0           323,000       32.49              Kabul         8,672  149.9
# 1           323,000       32.49              Kabul         8,672  149.9
# 2           323,000       32.49              Kabul         8,672  149.9
# 3           323,000       32.49              Kabul         8,672  149.9
# 4           323,000       32.49              Kabul         8,672  149.9
#
#   CPI CHANGE (%) CURRENCY-CODE  FERTILITY RATE FORESTED AREA (%)  \
# 0          2.30%           AFN            4.47             2.10%
# 1          2.30%           AFN            4.47             2.10%
# 2          2.30%           AFN            4.47             2.10%
# 3          2.30%           AFN            4.47             2.10%
# 4          2.30%           AFN            4.47             2.10%
#
#   GASOLINE PRICE               GDP GROSS PRIMARY EDUCATION ENROLLMENT (%)  \
# 0         $0.70   $19,101,353,833                                 104.00%
# 1         $0.70   $19,101,353,833                                 104.00%
# 2         $0.70   $19,101,353,833                                 104.00%
# 3         $0.70   $19,101,353,833                                 104.00%
# 4         $0.70   $19,101,353,833                                 104.00%
#
#    INFANT MORTALITY  LIFE EXPECTANCY  MATERNAL MORTALITY RATIO MINIMUM WAGE  \
# 0              47.9             64.5                     638.0       $0.43
# 1              47.9             64.5                     638.0       $0.43
# 2              47.9             64.5                     638.0       $0.43
# 3              47.9             64.5                     638.0       $0.43
# 4              47.9             64.5                     638.0       $0.43
#
#   OFFICIAL LANGUAGE OUT OF POCKET HEALTH EXPENDITURE  PHYSICIANS PER THOUSAND  \
# 0            Pashto                           78.40%                     0.28
# 1            Pashto                           78.40%                     0.28
# 2            Pashto                           78.40%                     0.28
# 3            Pashto                           78.40%                     0.28
# 4            Pashto                           78.40%                     0.28
#
#    POPULATION POPULATION: LABOR FORCE PARTICIPATION (%) TAX REVENUE (%)  \
# 0  38,041,754                                    48.90%           9.30%
# 1  38,041,754                                    48.90%           9.30%
# 2  38,041,754                                    48.90%           9.30%
# 3  38,041,754                                    48.90%           9.30%
# 4  38,041,754                                    48.90%           9.30%
#
#   TOTAL TAX RATE UNEMPLOYMENT RATE URBAN_POPULATION         DATE_TIME  \
# 0         71.40%            11.12%        9,797,273  21-03-2023 16:47
# 1         71.40%            11.12%        9,797,273  10-04-2016 10:28
# 2         71.40%            11.12%        9,797,273  26-10-2015 09:09
# 3         71.40%            11.12%        9,797,273  03-01-2009 20:23
# 4         71.40%            11.12%        9,797,273  12-12-2005 21:47
#
#    MAGNITUDE_Y
# 0          7.5
# 1          7.5
# 2          7.5
# 3          7.5
# 4          7.5

# %%
# We are now adding ordinal data that focuses on The Global Perceptions of Countries such as Corruption and Generosity
whr = pd.read_csv("WHR2023.csv")

#Converting the data to different Levels that we can use.

labels = ['Very Low', 'Low', 'Moderate', 'High', 'Very High']
levels = [1,2,3,4,5]
whr['Level Of Corruption'] = pd.cut(whr['Perceptions of corruption'], bins=5, labels = labels)
whr['Level Of Social Support in Society'] = pd.cut(whr['Social support'], bins=5, labels = labels)
whr['Generosity'] = pd.cut(whr['Generosity'], bins=5, labels = levels)
whr['Freedom to make life choices'] = pd.cut(whr['Freedom to make life choices'], bins=5, labels = levels)
whr['Ladder score'] = pd.cut(whr['Ladder score'], bins=5, labels = levels)

#Renaming Columns so we can have a common scheme

whr['COUNTRY'] = whr['Country name']
whr_filtered = whr[['COUNTRY', 'Generosity','Ladder score', 'Freedom to make life choices', 'Level Of Social Support in Society', 'Level Of Corruption']] 

#merging together all of our filtered data

data = pd.merge(data, whr_filtered, on='COUNTRY', how = 'left')
data.head()
# Out:
#        COUNTRY DENSITY\n(P/KM2) AGRICULTURAL LAND( %) LAND AREA(KM2)  \
# 0  Afghanistan               60                58.10%        652,230
# 1  Afghanistan               60                58.10%        652,230
# 2  Afghanistan               60                58.10%        652,230
# 3  Afghanistan               60                58.10%        652,230
# 4  Afghanistan               60                58.10%        652,230
#
#   ARMED FORCES SIZE  BIRTH RATE CAPITAL/MAJOR CITY CO2-EMISSIONS    CPI  \
# 0           323,000       32.49              Kabul         8,672  149.9
# 1           323,000       32.49              Kabul         8,672  149.9
# 2           323,000       32.49              Kabul         8,672  149.9
# 3           323,000       32.49              Kabul         8,672  149.9
# 4           323,000       32.49              Kabul         8,672  149.9
#
#   CPI CHANGE (%) CURRENCY-CODE  FERTILITY RATE FORESTED AREA (%)  \
# 0          2.30%           AFN            4.47             2.10%
# 1          2.30%           AFN            4.47             2.10%
# 2          2.30%           AFN            4.47             2.10%
# 3          2.30%           AFN            4.47             2.10%
# 4          2.30%           AFN            4.47             2.10%
#
#   GASOLINE PRICE               GDP GROSS PRIMARY EDUCATION ENROLLMENT (%)  \
# 0         $0.70   $19,101,353,833                                 104.00%
# 1         $0.70   $19,101,353,833                                 104.00%
# 2         $0.70   $19,101,353,833                                 104.00%
# 3         $0.70   $19,101,353,833                                 104.00%
# 4         $0.70   $19,101,353,833                                 104.00%
#
#    INFANT MORTALITY  LIFE EXPECTANCY  MATERNAL MORTALITY RATIO MINIMUM WAGE  \
# 0              47.9             64.5                     638.0       $0.43
# 1              47.9             64.5                     638.0       $0.43
# 2              47.9             64.5                     638.0       $0.43
# 3              47.9             64.5                     638.0       $0.43
# 4              47.9             64.5                     638.0       $0.43
#
#   OFFICIAL LANGUAGE OUT OF POCKET HEALTH EXPENDITURE  PHYSICIANS PER THOUSAND  \
# 0            Pashto                           78.40%                     0.28
# 1            Pashto                           78.40%                     0.28
# 2            Pashto                           78.40%                     0.28
# 3            Pashto                           78.40%                     0.28
# 4            Pashto                           78.40%                     0.28
#
#    POPULATION POPULATION: LABOR FORCE PARTICIPATION (%) TAX REVENUE (%)  \
# 0  38,041,754                                    48.90%           9.30%
# 1  38,041,754                                    48.90%           9.30%
# 2  38,041,754                                    48.90%           9.30%
# 3  38,041,754                                    48.90%           9.30%
# 4  38,041,754                                    48.90%           9.30%
#
#   TOTAL TAX RATE UNEMPLOYMENT RATE URBAN_POPULATION         DATE_TIME  \
# 0         71.40%            11.12%        9,797,273  21-03-2023 16:47
# 1         71.40%            11.12%        9,797,273  10-04-2016 10:28
# 2         71.40%            11.12%        9,797,273  26-10-2015 09:09
# 3         71.40%            11.12%        9,797,273  03-01-2009 20:23
# 4         71.40%            11.12%        9,797,273  12-12-2005 21:47
#
#    MAGNITUDE_Y Generosity Ladder score Freedom to make life choices  \
# 0          7.5          2            1                            1
# 1          7.5          2            1                            1
# 2          7.5          2            1                            1
# 3          7.5          2            1                            1
# 4          7.5          2            1                            1
#
#   Level Of Social Support in Society Level Of Corruption
# 0                           Very Low           Very High
# 1                           Very Low           Very High
# 2                           Very Low           Very High
# 3                           Very Low           Very High
# 4                           Very Low           Very High

# %%
# Reformating all of our chosen columns so we can do EDA

data['date'] = pd.to_datetime(data['DATE_TIME']).dt.date
data['density'] = data['DENSITY\n(P/KM2)']
data['GDP'] = data['GDP'].str.replace(',', '').str.replace(' ', '').str.replace('$', '').astype(float)
data['CO2-EMISSIONS'] = data['CO2-EMISSIONS'].str.replace(',', '').str.replace(' ', '')
data['FORESTED AREA (%)'] = data['FORESTED AREA (%)'].str.replace('%', '').str.replace(' ', '')
data['POPULATION'] = data['POPULATION'].str.replace(',', '').str.replace(' ', '')
data['TOTAL TAX RATE'] = data['TOTAL TAX RATE'].str.replace('%', '').str.replace(' ', '')
data['UNEMPLOYMENT RATE'] = data['UNEMPLOYMENT RATE'].str.replace('%', '').str.replace(' ', '')
data['MINIMUM WAGE'] = data['MINIMUM WAGE'].str.replace('$', '').astype(float)
data['density'] = pd.to_numeric(data['density'], errors='coerce')
data['FORESTED AREA (%)'] = pd.to_numeric(data['FORESTED AREA (%)'], errors='coerce')
data['PHYSICIANS PER THOUSAND'] = pd.to_numeric(data['PHYSICIANS PER THOUSAND'], errors='coerce')
data['TOTAL TAX RATE'] = pd.to_numeric(data['TOTAL TAX RATE'], errors='coerce')
data['UNEMPLOYMENT RATE'] = pd.to_numeric(data['UNEMPLOYMENT RATE'], errors='coerce')
data['CO2-EMISSIONS'] = pd.to_numeric(data['CO2-EMISSIONS'], errors='coerce')
data['POPULATION'] = pd.to_numeric(data['POPULATION'], errors='coerce')
# Out:
# /var/folders/rd/9nbcv3cs77b4zg8s993nhqrc0000gn/T/ipykernel_37900/3828072480.py:3: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['date'] = pd.to_datetime(data['DATE_TIME']).dt.date

# %%
data = data[['date', 'MAGNITUDE_Y', 'COUNTRY', 'CAPITAL/MAJOR CITY','CURRENCY-CODE', 'density', 'BIRTH RATE','CO2-EMISSIONS', 'FERTILITY RATE', 'FORESTED AREA (%)', 'GDP', 'INFANT MORTALITY',  'LIFE EXPECTANCY', 'MINIMUM WAGE', 'OFFICIAL LANGUAGE','PHYSICIANS PER THOUSAND', 'POPULATION', 'TOTAL TAX RATE', 'UNEMPLOYMENT RATE', 'Generosity', 'Ladder score','Freedom to make life choices', 'Level Of Social Support in Society', 'Level Of Corruption']]
data.head()
# Out:
#          date  MAGNITUDE_Y      COUNTRY CAPITAL/MAJOR CITY CURRENCY-CODE  \
# 0  2023-03-21          7.5  Afghanistan              Kabul           AFN
# 1  2016-04-10          7.5  Afghanistan              Kabul           AFN
# 2  2015-10-26          7.5  Afghanistan              Kabul           AFN
# 3  2009-01-03          7.5  Afghanistan              Kabul           AFN
# 4  2005-12-12          7.5  Afghanistan              Kabul           AFN
#
#    density  BIRTH RATE  CO2-EMISSIONS  FERTILITY RATE  FORESTED AREA (%)  \
# 0     60.0       32.49         8672.0            4.47                2.1
# 1     60.0       32.49         8672.0            4.47                2.1
# 2     60.0       32.49         8672.0            4.47                2.1
# 3     60.0       32.49         8672.0            4.47                2.1
# 4     60.0       32.49         8672.0            4.47                2.1
#
#             GDP  INFANT MORTALITY  LIFE EXPECTANCY  MINIMUM WAGE  \
# 0  1.910135e+10              47.9             64.5          0.43
# 1  1.910135e+10              47.9             64.5          0.43
# 2  1.910135e+10              47.9             64.5          0.43
# 3  1.910135e+10              47.9             64.5          0.43
# 4  1.910135e+10              47.9             64.5          0.43
#
#   OFFICIAL LANGUAGE  PHYSICIANS PER THOUSAND  POPULATION  TOTAL TAX RATE  \
# 0            Pashto                     0.28  38041754.0            71.4
# 1            Pashto                     0.28  38041754.0            71.4
# 2            Pashto                     0.28  38041754.0            71.4
# 3            Pashto                     0.28  38041754.0            71.4
# 4            Pashto                     0.28  38041754.0            71.4
#
#    UNEMPLOYMENT RATE Generosity Ladder score Freedom to make life choices  \
# 0              11.12          2            1                            1
# 1              11.12          2            1                            1
# 2              11.12          2            1                            1
# 3              11.12          2            1                            1
# 4              11.12          2            1                            1
#
#   Level Of Social Support in Society Level Of Corruption
# 0                           Very Low           Very High
# 1                           Very Low           Very High
# 2                           Very Low           Very High
# 3                           Very Low           Very High
# 4                           Very Low           Very High

# %%
data = data.drop_duplicates(subset= 'COUNTRY', keep= 'first')
data.to_csv('final_dataset', index=True)
final_dataset = pd.read_csv("final_dataset")
final_dataset = final_dataset.drop(final_dataset.columns[0], axis = 1)
final_dataset
# Out:
#            date  MAGNITUDE_Y      COUNTRY CAPITAL/MAJOR CITY CURRENCY-CODE  \
# 0    2023-03-21          7.5  Afghanistan              Kabul           AFN
# 1           NaN          NaN      Albania             Tirana           ALL
# 2    2003-05-21          6.8      Algeria            Algiers           DZD
# 3           NaN          NaN      Andorra   Andorra la Vella           EUR
# 4           NaN          NaN       Angola             Luanda           AOA
# ..          ...          ...          ...                ...           ...
# 190  2018-08-21          7.3    Venezuela            Caracas           VED
# 191         NaN          NaN      Vietnam              Hanoi           VND
# 192         NaN          NaN        Yemen              Sanaa           YER
# 193         NaN          NaN       Zambia             Lusaka           ZMW
# 194         NaN          NaN     Zimbabwe             Harare           NaN
#
#      density  BIRTH RATE  CO2-EMISSIONS  FERTILITY RATE  FORESTED AREA (%)  \
# 0       60.0       32.49         8672.0            4.47                2.1
# 1      105.0       11.78         4536.0            1.62               28.1
# 2       18.0       24.28       150006.0            3.02                0.8
# 3      164.0        7.20          469.0            1.27               34.0
# 4       26.0       40.73        34693.0            5.52               46.3
# ..       ...         ...            ...             ...                ...
# 190     32.0       17.88       164175.0            2.27               52.7
# 191    314.0       16.75       192668.0            2.05               48.1
# 192     56.0       30.45        10609.0            3.79                1.0
# 193     25.0       36.19         5141.0            4.63               65.2
# 194     38.0       30.68        10983.0            3.62               35.5
#
#               GDP  INFANT MORTALITY  LIFE EXPECTANCY  MINIMUM WAGE  \
# 0    1.910135e+10              47.9             64.5          0.43
# 1    1.527808e+10               7.8             78.5          1.12
# 2    1.699882e+11              20.1             76.7          0.95
# 3    3.154058e+09               2.7              NaN          6.63
# 4    9.463542e+10              51.6             60.8          0.71
# ..            ...               ...              ...           ...
# 190  4.823593e+11              21.4             72.1          0.01
# 191  2.619212e+11              16.5             75.3          0.73
# 192  2.691440e+10              42.9             66.1           NaN
# 193  2.306472e+10              40.4             63.5          0.24
# 194  2.144076e+10              33.9             61.2           NaN
#
#     OFFICIAL LANGUAGE  PHYSICIANS PER THOUSAND  POPULATION  TOTAL TAX RATE  \
# 0              Pashto                     0.28  38041754.0            71.4
# 1            Albanian                     1.20   2854191.0            36.6
# 2              Arabic                     1.72  43053054.0            66.1
# 3             Catalan                     3.33     77142.0             NaN
# 4          Portuguese                     0.21  31825295.0            49.1
# ..                ...                      ...         ...             ...
# 190           Spanish                     1.92  28515829.0            73.3
# 191        Vietnamese                     0.82  96462106.0            37.6
# 192            Arabic                     0.31  29161922.0            26.6
# 193           English                     1.19  17861030.0            15.6
# 194             Shona                     0.21  14645468.0            31.6
#
#      UNEMPLOYMENT RATE  Generosity  Ladder score  \
# 0                11.12         2.0           1.0
# 1                12.33         2.0           3.0
# 2                11.70         1.0           3.0
# 3                  NaN         NaN           NaN
# 4                 6.89         NaN           NaN
# ..                 ...         ...           ...
# 190               8.80         3.0           3.0
# 191               2.01         2.0           4.0
# 192              12.91         NaN           NaN
# 193              11.43         3.0           2.0
# 194               4.95         2.0           2.0
#
#      Freedom to make life choices Level Of Social Support in Society  \
# 0                             1.0                           Very Low
# 1                             4.0                           Moderate
# 2                             2.0                          Very High
# 3                             NaN                                NaN
# 4                             NaN                                NaN
# ..                            ...                                ...
# 190                           3.0                               High
# 191                           5.0                               High
# 192                           NaN                                NaN
# 193                           4.0                           Moderate
# 194                           3.0                           Moderate
#
#     Level Of Corruption
# 0             Very High
# 1             Very High
# 2                  High
# 3                   NaN
# 4                   NaN
# ..                  ...
# 190           Very High
# 191                High
# 192                 NaN
# 193           Very High
# 194                High
#
# [195 rows x 24 columns]

# %%
# final_dataset.to_csv('final_dataset', index=True)
final_dataset.size
# Out:
# 4680

# %%
print(final_dataset.describe())
# Out:
#        MAGNITUDE_Y     density  BIRTH RATE  CO2-EMISSIONS  FERTILITY RATE  \
# count    47.000000  188.000000  189.000000   1.880000e+02      188.000000
# mean      7.325532  139.281915   20.214974   1.777992e+05        2.698138
# std       0.621523  158.208082    9.945774   8.387903e+05        1.282267
# min       6.500000    2.000000    5.900000   1.100000e+01        0.980000
# 25%       6.800000   33.500000   11.300000   2.304250e+03        1.705000
# 50%       7.200000   83.000000   17.950000   1.230300e+04        2.245000
# 75%       7.750000  203.000000   28.750000   6.388425e+04        3.597500
# max       9.100000  847.000000   46.080000   9.893038e+06        6.910000
#
#        FORESTED AREA (%)           GDP  INFANT MORTALITY  LIFE EXPECTANCY  \
# count         188.000000  1.930000e+02        189.000000       187.000000
# mean           32.015426  4.772959e+11         21.332804        72.279679
# std            23.791331  2.172173e+12         19.548058         7.483661
# min             0.000000  4.727146e+07          1.400000        52.800000
# 25%            11.000000  8.454620e+09          6.000000        67.000000
# 50%            32.000000  3.438723e+10         14.000000        73.200000
# 75%            48.175000  2.340940e+11         32.700000        77.500000
# max            98.300000  2.142770e+13         84.500000        85.400000
#
#        MINIMUM WAGE  PHYSICIANS PER THOUSAND    POPULATION  TOTAL TAX RATE  \
# count    150.000000               188.000000  1.940000e+02      183.000000
# mean       2.194133                 1.839840  3.938116e+07       40.822404
# std        2.970796                 1.684261  1.450924e+08       20.557662
# min        0.010000                 0.010000  8.360000e+02        8.000000
# 25%        0.402500                 0.332500  1.962678e+06       30.600000
# 50%        1.045000                 1.460000  8.826588e+06       37.200000
# 75%        2.447500                 2.935000  2.858549e+07       48.000000
# max       13.590000                 8.420000  1.397715e+09      219.600000
#
#        UNEMPLOYMENT RATE  Generosity  Ladder score  \
# count         176.000000  127.000000    127.000000
# mean            6.886364    2.267717      3.582677
# std             5.079216    0.885947      0.946514
# min             0.090000    1.000000      1.000000
# 25%             3.395000    2.000000      3.000000
# 50%             5.360000    2.000000      4.000000
# 75%             9.490000    3.000000      4.000000
# max            28.180000    5.000000      5.000000
#
#        Freedom to make life choices
# count                    127.000000
# mean                       4.031496
# std                        0.958976
# min                        1.000000
# 25%                        4.000000
# 50%                        4.000000
# 75%                        5.000000
# max                        5.000000

# %%
# Calculate value counts for 'OFFICIAL LANGUAGE', 'Generosity', 'Ladder score',
# 'Freedom to make life choices', 'Level Of Social Support in Society', 'Level Of Corruption', and 'CURRENCY-CODE'
language_counts = final_dataset['OFFICIAL LANGUAGE'].value_counts().reset_index()
language_counts.columns = ['OFFICIAL LANGUAGE', 'Count']

generosity_counts = final_dataset['Generosity'].value_counts().reset_index()
generosity_counts.columns = ['Generosity', 'Count']

ladder_score_counts = final_dataset['Ladder score'].value_counts().reset_index()
ladder_score_counts.columns = ['Ladder score', 'Count']

freedom_counts = final_dataset['Freedom to make life choices'].value_counts().reset_index()
freedom_counts.columns = ['Freedom to make life choices', 'Count']

social_support_counts = final_dataset['Level Of Social Support in Society'].value_counts().reset_index()
social_support_counts.columns = ['Level Of Social Support in Society', 'Count']

corruption_counts = final_dataset['Level Of Corruption'].value_counts().reset_index()
corruption_counts.columns = ['Level Of Corruption', 'Count']

currency_code_counts = final_dataset['CURRENCY-CODE'].value_counts().reset_index()
currency_code_counts.columns = ['CURRENCY-CODE', 'Count']


# Print the results side by side
print("OFFICIAL LANGUAGE counts:")
print(language_counts)

print("\nGenerosity counts:")
print(generosity_counts)

print("\nLadder score counts:")
print(ladder_score_counts)

print("\nFreedom to make life choices counts:")
print(freedom_counts)

print("\nLevel Of Social Support in Society counts:")
print(social_support_counts)

print("\nLevel Of Corruption counts:")
print(corruption_counts)

print("\nCURRENCY-CODE counts:")
print(currency_code_counts)
# Out:
# OFFICIAL LANGUAGE counts:
#    OFFICIAL LANGUAGE  Count
# 0            English     31
# 1             French     25
# 2            Spanish     19
# 3             Arabic     18
# 4         Portuguese      7
# ..               ...    ...
# 71          Albanian      1
# 72  Jamaican English      1
# 73               Lao      1
# 74           Latvian      1
# 75             Shona      1
#
# [76 rows x 2 columns]
#
# Generosity counts:
#    Generosity  Count
# 0         2.0     56
# 1         3.0     38
# 2         1.0     24
# 3         4.0      7
# 4         5.0      2
#
# Ladder score counts:
#    Ladder score  Count
# 0           4.0     53
# 1           3.0     37
# 2           5.0     20
# 3           2.0     15
# 4           1.0      2
#
# Freedom to make life choices counts:
#    Freedom to make life choices  Count
# 0                           4.0     50
# 1                           5.0     46
# 2                           3.0     23
# 3                           2.0      5
# 4                           1.0      3
#
# Level Of Social Support in Society counts:
#   Level Of Social Support in Society  Count
# 0                          Very High     55
# 1                               High     39
# 2                           Moderate     20
# 3                                Low     11
# 4                           Very Low      2
#
# Level Of Corruption counts:
#   Level Of Corruption  Count
# 0           Very High     63
# 1                High     41
# 2            Moderate     10
# 3            Very Low      7
# 4                 Low      6
#
# CURRENCY-CODE counts:
#     CURRENCY-CODE  Count
# 0             EUR     23
# 1             XOF      8
# 2             XCD      6
# 3             USD      6
# 4             XAF      5
# ..            ...    ...
# 128           GMD      1
# 129           FJD      1
# 130           ETB      1
# 131           ERN      1
# 132           ZMW      1
#
# [133 rows x 2 columns]

# %%
final_dataset['date'].dtypes
# Out:
# dtype('O')

# %%
#THis is just to find the Cardinality of our Temporal Variables
final_dataset.to_csv('scrap_set', index=True)
scrap_set = pd.read_csv('scrap_set')

scrap_set['date'] = pd.to_datetime(scrap_set['date'])

# Find the minimum and maximum dates in the column
date_min = scrap_set['date'].min()
date_max = scrap_set['date'].max()

print(f"Minimum Date: {date_min}")
print(f"Maximum Date: {date_max}")
# Out:
# Minimum Date: 1995-11-22 00:00:00
# Maximum Date: 2023-08-16 00:00:00

# %%
#This is because, 
# final_dataset['MAGNITUDE_Y'] = final_dataset['MAGNITUDE_Y'].fillna(0)
final_dataset['GDP_PER_CAPITA'] = final_dataset['GDP'] / final_dataset['POPULATION']
final_dataset.head()
# Out:
#          date  MAGNITUDE_Y      COUNTRY CAPITAL/MAJOR CITY CURRENCY-CODE  \
# 0  2023-03-21          7.5  Afghanistan              Kabul           AFN
# 1         NaN          NaN      Albania             Tirana           ALL
# 2  2003-05-21          6.8      Algeria            Algiers           DZD
# 3         NaN          NaN      Andorra   Andorra la Vella           EUR
# 4         NaN          NaN       Angola             Luanda           AOA
#
#    density  BIRTH RATE  CO2-EMISSIONS  FERTILITY RATE  FORESTED AREA (%)  \
# 0     60.0       32.49         8672.0            4.47                2.1
# 1    105.0       11.78         4536.0            1.62               28.1
# 2     18.0       24.28       150006.0            3.02                0.8
# 3    164.0        7.20          469.0            1.27               34.0
# 4     26.0       40.73        34693.0            5.52               46.3
#
#             GDP  INFANT MORTALITY  LIFE EXPECTANCY  MINIMUM WAGE  \
# 0  1.910135e+10              47.9             64.5          0.43
# 1  1.527808e+10               7.8             78.5          1.12
# 2  1.699882e+11              20.1             76.7          0.95
# 3  3.154058e+09               2.7              NaN          6.63
# 4  9.463542e+10              51.6             60.8          0.71
#
#   OFFICIAL LANGUAGE  PHYSICIANS PER THOUSAND  POPULATION  TOTAL TAX RATE  \
# 0            Pashto                     0.28  38041754.0            71.4
# 1          Albanian                     1.20   2854191.0            36.6
# 2            Arabic                     1.72  43053054.0            66.1
# 3           Catalan                     3.33     77142.0             NaN
# 4        Portuguese                     0.21  31825295.0            49.1
#
#    UNEMPLOYMENT RATE  Generosity  Ladder score  Freedom to make life choices  \
# 0              11.12         2.0           1.0                           1.0
# 1              12.33         2.0           3.0                           4.0
# 2              11.70         1.0           3.0                           2.0
# 3                NaN         NaN           NaN                           NaN
# 4               6.89         NaN           NaN                           NaN
#
#   Level Of Social Support in Society Level Of Corruption  GDP_PER_CAPITA
# 0                           Very Low           Very High      502.115487
# 1                           Moderate           Very High     5352.857411
# 2                          Very High                High     3948.343279
# 3                                NaN                 NaN    40886.391162
# 4                                NaN                 NaN     2973.591160

# %%
print(final_dataset.describe())
#Includes GDP Per Capita
# Out:
#        MAGNITUDE_Y     density  BIRTH RATE  CO2-EMISSIONS  FERTILITY RATE  \
# count    47.000000  188.000000  189.000000   1.880000e+02      188.000000
# mean      7.325532  139.281915   20.214974   1.777992e+05        2.698138
# std       0.621523  158.208082    9.945774   8.387903e+05        1.282267
# min       6.500000    2.000000    5.900000   1.100000e+01        0.980000
# 25%       6.800000   33.500000   11.300000   2.304250e+03        1.705000
# 50%       7.200000   83.000000   17.950000   1.230300e+04        2.245000
# 75%       7.750000  203.000000   28.750000   6.388425e+04        3.597500
# max       9.100000  847.000000   46.080000   9.893038e+06        6.910000
#
#        FORESTED AREA (%)           GDP  INFANT MORTALITY  LIFE EXPECTANCY  \
# count         188.000000  1.930000e+02        189.000000       187.000000
# mean           32.015426  4.772959e+11         21.332804        72.279679
# std            23.791331  2.172173e+12         19.548058         7.483661
# min             0.000000  4.727146e+07          1.400000        52.800000
# 25%            11.000000  8.454620e+09          6.000000        67.000000
# 50%            32.000000  3.438723e+10         14.000000        73.200000
# 75%            48.175000  2.340940e+11         32.700000        77.500000
# max            98.300000  2.142770e+13         84.500000        85.400000
#
#        MINIMUM WAGE  PHYSICIANS PER THOUSAND    POPULATION  TOTAL TAX RATE  \
# count    150.000000               188.000000  1.940000e+02      183.000000
# mean       2.194133                 1.839840  3.938116e+07       40.822404
# std        2.970796                 1.684261  1.450924e+08       20.557662
# min        0.010000                 0.010000  8.360000e+02        8.000000
# 25%        0.402500                 0.332500  1.962678e+06       30.600000
# 50%        1.045000                 1.460000  8.826588e+06       37.200000
# 75%        2.447500                 2.935000  2.858549e+07       48.000000
# max       13.590000                 8.420000  1.397715e+09      219.600000
#
#        UNEMPLOYMENT RATE  Generosity  Ladder score  \
# count         176.000000  127.000000    127.000000
# mean            6.886364    2.267717      3.582677
# std             5.079216    0.885947      0.946514
# min             0.090000    1.000000      1.000000
# 25%             3.395000    2.000000      3.000000
# 50%             5.360000    2.000000      4.000000
# 75%             9.490000    3.000000      4.000000
# max            28.180000    5.000000      5.000000
#
#        Freedom to make life choices  GDP_PER_CAPITA
# count                    127.000000      193.000000
# mean                       4.031496    15690.877246
# std                        0.958976    25268.434004
# min                        1.000000      261.247473
# 25%                        4.000000     1912.903745
# 50%                        4.000000     5955.109010
# 75%                        5.000000    17401.721516
# max                        5.000000   184396.986783

# %%
density_hist = alt.Chart(final_dataset).mark_bar().encode(
    alt.X('density:Q', bin=alt.BinParams(maxbins=20)),
    alt.Y('count()')
).properties(
    title = 'Population Density of the World'
)
birth_rate_hist = alt.Chart(final_dataset).mark_bar().encode(
    alt.X('BIRTH RATE:Q', bin=alt.BinParams(maxbins=12)),
    alt.Y('count()')
).properties(
    title = 'The Birth Rate of the World'
)
co2_hist = alt.Chart(final_dataset).mark_bar().encode(
    alt.X('CO2-EMISSIONS:Q', bin=alt.BinParams(maxbins=12)),
    alt.Y('count()')
).properties(
    title = 'What do CO2 Emissions look like Overall?'
)
fort_hist = alt.Chart(final_dataset).mark_bar().encode(
    alt.X('FORESTED AREA (%):Q', bin=alt.BinParams(maxbins=12)),
    alt.Y('count()')
).properties(
    title = 'What does the Forested Rate Look Like Overall ?'
)
gdp_plot = alt.Chart(final_dataset).mark_boxplot().encode(
    alt.X('Level Of Corruption'),
    alt.Y('GDP_PER_CAPITA')
).properties(width=400, height=300,
             title = 'How Does the Corruption Level Realate to the GDP per Capita')

corruptionvsunemployment_plot = alt.Chart(final_dataset).mark_boxplot().encode(
    alt.X('Level Of Corruption'),
    alt.Y('UNEMPLOYMENT RATE')
).properties(width=400, height=300,
             title = 'How does Level of Corruption Realte to Unemployment Rate' )

country_plot = alt.Chart(final_dataset).mark_circle().encode(
    alt.X('COUNTRY'),
    alt.Y('UNEMPLOYMENT RATE'),
    alt.Color('OFFICIAL LANGUAGE')
).properties(
    title = 'How the Unemplyment Rate of Countries differs and its effect on Official Languages'
)



country_gdp_plot = alt.Chart(final_dataset).mark_bar().encode(
    alt.X('COUNTRY'),
    alt.Y('GDP_PER_CAPITA', title = 'GDP per Capita'),
    alt.Color('UNEMPLOYMENT RATE')
).properties(
    title = 'GDP per capita of different nations and their unemployment rates'
)

# %%
alt.vconcat(
    alt.hconcat(density_hist.properties(width=400, height=300), 
                birth_rate_hist.properties(width=400, height=300)),
    alt.hconcat(
        co2_hist.properties(width=400, height=300),
        fort_hist.properties(width=400, height=300)  # Set width and height as needed
    ),
    title='Histogram Dashboard'
).resolve_legend(
    color='independent'
).configure_axis(
    labelAngle=0
)
# Out:
# alt.VConcatChart(...)

# %%
alt.vconcat(
    alt.hconcat(country_gdp_plot.encode(alt.X('COUNTRY', axis = alt.Axis(labelAngle=-45)))),
    alt.hconcat(
        gdp_plot.properties(width=400, height=300)  # Set width and height as needed
    ),
    alt.hconcat(country_plot.encode(alt.X('COUNTRY', axis = alt.Axis(labelAngle=-45))),),
    title='Univariate Plot Dashboard'
).resolve_legend(
    color='independent'
).configure_axis(
    labelAngle=0
)
# Out:
# alt.VConcatChart(...)

# %%
alt.vconcat(
    alt.hconcat(density_hist.properties(width=400, height=300), 
                birth_rate_hist.properties(width=400, height=300)),
    alt.hconcat(
        corruptionvsunemployment_plot.properties(width=400, height=300),
        gdp_plot.properties(width=400, height=300)  # Set width and height as needed
    ),
    title='Some Plots'
).resolve_legend(
    color='independent'
).configure_axis(
    labelAngle=0
)
# Out:
# alt.VConcatChart(...)

# %%
generosity_gdp = alt.Chart(final_dataset).mark_bar().encode(
    alt.X('Generosity:O'),
    alt.Y('Level Of Corruption:O'),
    alt.Color('GDP_PER_CAPITA')
).properties(
    title = 'Looking at Generosity and Levels of Corruption and how they relate to GDP per Capita'
)

gdp_tax = alt.Chart(final_dataset).mark_circle().encode(
    alt.X('GDP_PER_CAPITA:Q').bin(),
    alt.Color('COUNTRY'),
    alt
    .Y('TOTAL TAX RATE:Q').bin()
).properties(
    title = 'Looking at GDP per Capitas of Different Countries and their Total Tax Rates'
)

gdp_tax_box = alt.Chart(final_dataset).mark_boxplot().encode(
    x=alt.X('TOTAL TAX RATE', title='Tax Rate', scale=alt.Scale(domain=[20, 85])),
    y=alt.Y('GDP_PER_CAPITA:Q', title='GDP per Capita'),
    color=alt.Color('TOTAL TAX RATE:N', legend=alt.Legend(title='Tax Rate')),
    tooltip=['TOTAL TAX RATE:N', 'GDPpercapita:Q']
).properties(
    title = 'The Relationship between Total Tax Rate and GDP Per Capita'
)

forest_co2 = alt.Chart(final_dataset).mark_bar().encode(
    alt.X('FORESTED AREA (%)'),
    alt.Y('CO2-EMISSIONS'),
    alt.Color('density')
).properties(
    title = 'The Relationship between CO2 Emissions and Forested area, by density'
)

# %%
alt.vconcat(
    alt.hconcat(generosity_gdp.properties(width=400, height=300), 
                gdp_tax.properties(width=400, height=300)),
    alt.hconcat(
        forest_co2.properties(width=400, height=300) , # Set width and height as needed
        gdp_tax_box.properties(width=400, height=300)
    ),
    title='Multi-Variate Plot Dashboard'
).resolve_legend(
    color='independent'
).configure_axis(
    labelAngle=0
)
# Out:
# alt.VConcatChart(...)

# %%
final_dataset.to_csv('final_dataset', index=True)
print('Hello_World')
# Out:
# Hello_World

# %%
### Milestone 2

# %%
import altair as alt
from vega_datasets import data
from altair import datum

source = data.iris()

alt.Chart(source).transform_window(
    index='count()'
).transform_fold(
    ['petalLength', 'petalWidth', 'sepalLength', 'sepalWidth']
).transform_joinaggregate(
     min='min(value)',
     max='max(value)',
     groupby=['key']
).transform_calculate(
    minmax_value=(datum.value-datum.min)/(datum.max-datum.min),
    mid=(datum.min+datum.max)/2
).mark_line().encode(
    x='key:N',
    y='minmax_value:Q',
    color='species:N',
    detail='index:N',
    opacity=alt.value(0.5)
).properties(width=500)
# Out:
# alt.Chart(...)

# %%
# labels = ['Very Low', 'Low', 'Moderate', 'High', 'Very High']
# levels = [1,2,3,4,5]
# whr['Level Of Corruption'] = pd.cut(whr['Perceptions of corruption'], bins=5, labels = labels)
# whr['Level Of Social Support in Society'] = pd.cut(whr['Social support'], bins=5, labels = labels)
# whr['Generosity'] = pd.cut(whr['Generosity'], bins=5, labels = levels)
# whr['Freedom to make life choices'] = pd.cut(whr['Freedom to make life choices'], bins=5, labels = levels)
# whr['Ladder score'] = pd.cut(whr['Ladder score'], bins=5, labels = levels)

td = final_dataset

td['Numerical Level Of Social Support in Society'] = pd.cut(whr['Social support'], bins=5, labels = levels)
td['Numerical Level Of Corruption'] = pd.cut(whr['Perceptions of corruption'], bins=5, labels = levels)


alt.Chart(td).transform_window(
    index='count()'
).transform_fold(
    ['Numerical Level Of Corruption','Ladder score', 'Freedom to make life choices', 'Numerical Level Of Social Support in Society']
).transform_joinaggregate(
     min='min(value)',
     max='max(value)',
     groupby=['key']
).transform_calculate(
    minmax_value=(datum.value-datum.min)/(datum.max-datum.min),
    mid=(datum.min+datum.max)/2
).mark_line().encode(
    x='key:N',
    y='minmax_value:Q',
    color='TOTAL TAX RATE',
    detail='index:N',
    opacity=alt.value(0.5)
).properties(width=500)
# Out:
# alt.Chart(...)

# %%
final_dataset.head()
# Out:
#          date  MAGNITUDE_Y      COUNTRY CAPITAL/MAJOR CITY CURRENCY-CODE  \
# 0  2023-03-21          7.5  Afghanistan              Kabul           AFN
# 1         NaN          NaN      Albania             Tirana           ALL
# 2  2003-05-21          6.8      Algeria            Algiers           DZD
# 3         NaN          NaN      Andorra   Andorra la Vella           EUR
# 4         NaN          NaN       Angola             Luanda           AOA
#
#    density  BIRTH RATE  CO2-EMISSIONS  FERTILITY RATE  FORESTED AREA (%)  \
# 0     60.0       32.49         8672.0            4.47                2.1
# 1    105.0       11.78         4536.0            1.62               28.1
# 2     18.0       24.28       150006.0            3.02                0.8
# 3    164.0        7.20          469.0            1.27               34.0
# 4     26.0       40.73        34693.0            5.52               46.3
#
#             GDP  INFANT MORTALITY  LIFE EXPECTANCY  MINIMUM WAGE  \
# 0  1.910135e+10              47.9             64.5          0.43
# 1  1.527808e+10               7.8             78.5          1.12
# 2  1.699882e+11              20.1             76.7          0.95
# 3  3.154058e+09               2.7              NaN          6.63
# 4  9.463542e+10              51.6             60.8          0.71
#
#   OFFICIAL LANGUAGE  PHYSICIANS PER THOUSAND  POPULATION  TOTAL TAX RATE  \
# 0            Pashto                     0.28  38041754.0            71.4
# 1          Albanian                     1.20   2854191.0            36.6
# 2            Arabic                     1.72  43053054.0            66.1
# 3           Catalan                     3.33     77142.0             NaN
# 4        Portuguese                     0.21  31825295.0            49.1
#
#    UNEMPLOYMENT RATE  Generosity  Ladder score  Freedom to make life choices  \
# 0              11.12         2.0           1.0                           1.0
# 1              12.33         2.0           3.0                           4.0
# 2              11.70         1.0           3.0                           2.0
# 3                NaN         NaN           NaN                           NaN
# 4               6.89         NaN           NaN                           NaN
#
#   Level Of Social Support in Society Level Of Corruption  GDP_PER_CAPITA  \
# 0                           Very Low           Very High      502.115487
# 1                           Moderate           Very High     5352.857411
# 2                          Very High                High     3948.343279
# 3                                NaN                 NaN    40886.391162
# 4                                NaN                 NaN     2973.591160
#
#   Numerical Level Of Social Support in Society Numerical Level Of Corruption
# 0                                            5                             1
# 1                                            5                             1
# 2                                            5                             4
# 3                                            5                             4
# 4                                            5                             2
